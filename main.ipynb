# %%
import os
from typing import Final
from pathlib import Path
from dotenv import load_dotenv
from neo4j import GraphDatabase
from core.graph import GraphRAGPOC
# Out:
# /home/tanul-kumar-srivastava/workspace/graph-rag-poc/.venv/lib/python3.11/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (1.26.18) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(

# %%
ENV_PATH: Final[Path] = "./.env.poc"
CHUNKS: Final[Path] = "./dataset/chunks.jsonl"

load_dotenv(dotenv_path=ENV_PATH)

driver = GraphDatabase.driver(
    os.getenv("NEO4J_URI"),
    auth=(os.getenv("NEO4J_USERNAME"), os.getenv("NEO4J_PASSWORD"))
)

# %%
obj = GraphRAGPOC(groq_api=os.getenv("GROQ_API_KEY"),
                  groq_model=os.getenv("GROQ_LLM_MODEL"),
                  neo4j_driver=driver,
                  chunks_path=CHUNKS)
# Out:
# 2026-03-15 17:14:01 | INFO | core.utils | Session created
# 2026-03-15 17:14:02 | INFO | core.graph | LLM initialized | model=llama-3.3-70b-versatile
# 2026-03-15 17:14:02 | INFO | core.graph | Neo4j session created successfully
# 2026-03-15 17:14:02 | INFO | core.graph | Documents loaded | total_chunks=1428
# 2026-03-15 17:14:02 | INFO | core.graph | Building LangGraph workflow
# 2026-03-15 17:14:02 | INFO | core.graph | Workflow entry point set
# 2026-03-15 17:14:02 | INFO | core.graph | Workflow edges configured
# 2026-03-15 17:14:02 | INFO | core.graph | LangGraph workflow compiled successfully

# %%
query = "Any update on chinese alumina production?"

# %%
response = obj.get_response(query=query)
# Out:
# 2026-03-15 17:14:02 | INFO | core.graph | Workflow execution started | query=Any update on chinese alumina production?
# 2026-03-15 17:14:02 | INFO | core.graph | Node started | get_cypher_query
# 2026-03-15 17:14:09 | INFO | core.utils | Node schema information fetched
# 2026-03-15 17:14:09 | INFO | core.utils | Relationship schema information fetched
# 2026-03-15 17:14:09 | INFO | core.utils | Node property information fetched
# 2026-03-15 17:14:11 | INFO | core.graph | Cypher query generated
# 2026-03-15 17:14:11 | INFO | core.graph | Node started | get_valid_chunks
# 2026-03-15 17:14:11 | INFO | core.graph | Cypher query executed | rows=25 cols=8
# 2026-03-15 17:14:11 | INFO | core.graph | Chunk ID columns detected | columns=['n.chunk_id', 'm.chunk_id']
# 2026-03-15 17:14:11 | INFO | core.graph | Valid chunks extracted | count=7
# 2026-03-15 17:14:11 | INFO | core.graph | Node started | get_context
# 2026-03-15 17:14:11 | INFO | core.graph | Context assembled | chunks_used=7
# 2026-03-15 17:14:11 | INFO | core.graph | Node started | get_final_response
# 2026-03-15 17:14:12 | INFO | core.graph | Final response generated
# 2026-03-15 17:14:12 | INFO | core.graph | Workflow execution completed

# %%
print(response)
# Out:
# According to the provided context, there is an update on Chinese alumina production. The article titled "WEEKLY: China's alumina output edges down, stocks continue to climb" suggests that China's alumina output has decreased, while stocks continue to rise. However, the exact figures and dates for this decrease are not specified in the given context.
